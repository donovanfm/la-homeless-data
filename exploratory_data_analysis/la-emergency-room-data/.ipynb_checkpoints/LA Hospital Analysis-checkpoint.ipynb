# %%
import pandas as pd
import re

# %%
erData = pd.read_csv("Emergency_Department_Encounters_and_Admits_by_Principal_Diagnosis_Group_2010-2014.csv")
hospitalData = pd.read_csv("Hospital_Building_Data.csv")

# %%
erData.head()
# Out:
#    Year   oshpd_id     FACILITY_NAME COUNTY_NAME          Type_Of_Control  \
# 0  2014  106010735  ALAMEDA HOSPITAL     ALAMEDA  Public - City or County
# 1  2014  106010735  ALAMEDA HOSPITAL     ALAMEDA  Public - City or County
# 2  2014  106010735  ALAMEDA HOSPITAL     ALAMEDA  Public - City or County
# 3  2014  106010735  ALAMEDA HOSPITAL     ALAMEDA  Public - City or County
# 4  2014  106010735  ALAMEDA HOSPITAL     ALAMEDA  Public - City or County
#
#             ED_Level    Source             Principal Diagnosis Group  Count
# 0  Emergency - Basic  ED Visit                       All Pregnancies    176
# 1  Emergency - Basic  ED Visit            Blood/Blood-forming Organs     42
# 2  Emergency - Basic  ED Visit                           Circulatory    244
# 3  Emergency - Basic  ED Visit  Congenital Anomalies (Birth Defects)      2
# 4  Emergency - Basic  ED Visit                             Digestive    738

# %%
hospitalData.head()
# Out:
#     County Code  Perm ID     Facility Name Building Nbr       Building Name  \
# 0  01 - Alameda    11210  Alameda Hospital    BLD-01278   Original Hospital
# 1  01 - Alameda    11210  Alameda Hospital    BLD-01279       Stephens Wing
# 2  01 - Alameda    11210  Alameda Hospital    BLD-01280           West Wing
# 3  01 - Alameda    11210  Alameda Hospital    BLD-01281          South Wing
# 4  01 - Alameda    11210  Alameda Hospital    BLD-01282  Radiology Addition
#
#   Building Status SPC Rating *  \
# 0      In Service            1
# 1      In Service            1
# 2      In Service            2
# 3      In Service           3s
# 4      In Service           5s
#
#                                         Building URL  Height (ft)  Stories  \
# 0  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        44.17        4
# 1  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        35.00        3
# 2  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        2
# 3  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        3
# 4  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        2
#
#                          Building Code  Building Code Year  Year Completed  \
# 0                              Unknown                 NaN            1926
# 1     1952 Uniform Building Code (UBC)                1952            1956
# 2     1964 Uniform Building Code (UBC)                1964            1968
# 3  1976 California Building Code (CBC)                1976            1983
# 4  1985 California Building Code (CBC)                1985            1995
#
#    Count                           Location 1
# 0      1  Alameda\n(37.7626572, -122.2538986)
# 1      1  Alameda\n(37.7626572, -122.2538986)
# 2      1  Alameda\n(37.7626572, -122.2538986)
# 3      1  Alameda\n(37.7626572, -122.2538986)
# 4      1  Alameda\n(37.7626572, -122.2538986)

# %%
latValues = hospitalData["Location 1"].map(lambda loc: re.search("\d+(\.\d+)?", loc))
lonValues = hospitalData["Location 1"].map(lambda loc: re.search("-\d+(\.\d+)?", loc))

# %%
hospitalData["lat"] = [float(x.group(0)) for x in latValues]
hospitalData["lon"] = [float(x.group(0)) for x in lonValues]
hospitalData.head()
# Out:
#     County Code  Perm ID     Facility Name Building Nbr       Building Name  \
# 0  01 - Alameda    11210  Alameda Hospital    BLD-01278   Original Hospital
# 1  01 - Alameda    11210  Alameda Hospital    BLD-01279       Stephens Wing
# 2  01 - Alameda    11210  Alameda Hospital    BLD-01280           West Wing
# 3  01 - Alameda    11210  Alameda Hospital    BLD-01281          South Wing
# 4  01 - Alameda    11210  Alameda Hospital    BLD-01282  Radiology Addition
#
#   Building Status SPC Rating *  \
# 0      In Service            1
# 1      In Service            1
# 2      In Service            2
# 3      In Service           3s
# 4      In Service           5s
#
#                                         Building URL  Height (ft)  Stories  \
# 0  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        44.17        4
# 1  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        35.00        3
# 2  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        2
# 3  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        3
# 4  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        2
#
#                          Building Code  Building Code Year  Year Completed  \
# 0                              Unknown                 NaN            1926
# 1     1952 Uniform Building Code (UBC)                1952            1956
# 2     1964 Uniform Building Code (UBC)                1964            1968
# 3  1976 California Building Code (CBC)                1976            1983
# 4  1985 California Building Code (CBC)                1985            1995
#
#    Count                           Location 1        lat         lon
# 0      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 1      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 2      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 3      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 4      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899

# %%
hospitalData["Facility Name"] = hospitalData["Facility Name"].map(lambda name: name.upper())
hospitalData.head()
# Out:
#     County Code  Perm ID     Facility Name Building Nbr       Building Name  \
# 0  01 - Alameda    11210  ALAMEDA HOSPITAL    BLD-01278   Original Hospital
# 1  01 - Alameda    11210  ALAMEDA HOSPITAL    BLD-01279       Stephens Wing
# 2  01 - Alameda    11210  ALAMEDA HOSPITAL    BLD-01280           West Wing
# 3  01 - Alameda    11210  ALAMEDA HOSPITAL    BLD-01281          South Wing
# 4  01 - Alameda    11210  ALAMEDA HOSPITAL    BLD-01282  Radiology Addition
#
#   Building Status SPC Rating *  \
# 0      In Service            1
# 1      In Service            1
# 2      In Service            2
# 3      In Service           3s
# 4      In Service           5s
#
#                                         Building URL  Height (ft)  Stories  \
# 0  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        44.17        4
# 1  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        35.00        3
# 2  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        2
# 3  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        3
# 4  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        2
#
#                          Building Code  Building Code Year  Year Completed  \
# 0                              Unknown                 NaN            1926
# 1     1952 Uniform Building Code (UBC)                1952            1956
# 2     1964 Uniform Building Code (UBC)                1964            1968
# 3  1976 California Building Code (CBC)                1976            1983
# 4  1985 California Building Code (CBC)                1985            1995
#
#    Count                           Location 1        lat         lon
# 0      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 1      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 2      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 3      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899
# 4      1  Alameda\n(37.7626572, -122.2538986)  37.762657 -122.253899

# %%
laHospitalData = hospitalData[hospitalData["County Code"] == "19 - Los Angeles"]
laHospitalData = laHospitalData.drop_duplicates(subset="Facility Name")
laHospitalData.head()
# Out:
#           County Code  Perm ID  \
# 609  19 - Los Angeles    11386
# 610  19 - Los Angeles    11399
# 635  19 - Los Angeles    11417
# 644  19 - Los Angeles    11441
# 655  19 - Los Angeles    11480
#
#                                         Facility Name Building Nbr  \
# 609                  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 610                          ANTELOPE VALLEY HOSPITAL    BLD-00737
# 635                       BARLOW RESPIRATORY HOSPITAL    BLD-00730
# 644                                  BEVERLY HOSPITAL    BLD-00613
# 655  CALIFORNIA HOSPITAL MEDICAL CENTER - LOS ANGELES    BLD-00622
#
#                               Building Name Building Status SPC Rating *  \
# 609                                Hospital      In Service            2
# 610                       Original Hospital      In Service            1
# 635        Outpatient Clinic & Lab Addition      In Service            4
# 644  Service Building & Additions (Block I)      In Service            1
# 655                        Tibbitts Tower A      In Service            3
#
#                                           Building URL  Height (ft)  Stories  \
# 609  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...         64.0        5
# 610  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...         34.5        3
# 635  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...         23.0        2
# 644  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...         10.0        1
# 655  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        8
#
#                            Building Code  Building Code Year  Year Completed  \
# 609     1967 Uniform Building Code (UBC)                1967            1971
# 610     1952 County of Los Angeles (LAC)                1952            1954
# 635  1976 California Building Code (CBC)                1976            1980
# 644     1949 Uniform Building Code (UBC)                1949            1952
# 655  1979 California Building Code (CBC)                1979            1987
#
#      Count                               Location 1        lat         lon
# 609      1     Alhambra\n(34.0904846, -118.1440964)  34.090485 -118.144096
# 610      1    Lancaster\n(34.6877708, -118.1579819)  34.687771 -118.157982
# 635      1  Los Angeles\n(34.0754242, -118.2474213)  34.075424 -118.247421
# 644      1   Montebello\n(34.0150566, -118.1006393)  34.015057 -118.100639
# 655      1  Los Angeles\n(34.0371506, -118.2654666)  34.037151 -118.265467

# %%
# %matplotlib inline

from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

mapMargin = 0.1
lowerLat = min(laHospitalData["lat"]) - mapMargin
upperLat = max(laHospitalData["lat"]) + mapMargin
lowerLon = min(laHospitalData["lon"]) - mapMargin
upperLon = max(laHospitalData["lon"]) + mapMargin
m = Basemap(projection='cass',llcrnrlat=lowerLat,urcrnrlat=upperLat,\
            llcrnrlon=lowerLon,urcrnrlon=upperLon,lat_ts=20,resolution='h',lon_0=(upperLon + lowerLon)/2.0,lat_0=(upperLat + lowerLat)/2.0)
m.drawcoastlines()
m.fillcontinents(color='#ffcccc',lake_color='aqua',zorder=0)
# draw parallels and meridians.
#m.drawparallels(np.arange(-90.,91.,30.))
#m.drawmeridians(np.arange(-180.,181.,60.))
m.drawmapboundary(fill_color='aqua')
x, y = m(laHospitalData["lon"].values, laHospitalData["lat"].values)
m.scatter(x, y, marker='o', color='k', s=2)
plt.title("Locations of LA Hospitals")
plt.show()

# %%
laERData = pd.merge(laHospitalData, erData, left_on="Facility Name", right_on="FACILITY_NAME", how="left")
laERData.head(20)
# Out:
#          County Code  Perm ID                     Facility Name Building Nbr  \
# 0   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 1   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 2   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 3   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 4   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 5   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 6   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 7   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 8   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 9   19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 10  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 11  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 12  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 13  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 14  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 15  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 16  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 17  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 18  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 19  19 - Los Angeles    11386  ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
#
#    Building Name Building Status SPC Rating *  \
# 0       Hospital      In Service            2
# 1       Hospital      In Service            2
# 2       Hospital      In Service            2
# 3       Hospital      In Service            2
# 4       Hospital      In Service            2
# 5       Hospital      In Service            2
# 6       Hospital      In Service            2
# 7       Hospital      In Service            2
# 8       Hospital      In Service            2
# 9       Hospital      In Service            2
# 10      Hospital      In Service            2
# 11      Hospital      In Service            2
# 12      Hospital      In Service            2
# 13      Hospital      In Service            2
# 14      Hospital      In Service            2
# 15      Hospital      In Service            2
# 16      Hospital      In Service            2
# 17      Hospital      In Service            2
# 18      Hospital      In Service            2
# 19      Hospital      In Service            2
#
#                                          Building URL  Height (ft)  Stories  \
# 0   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 1   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 2   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 3   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 4   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 5   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 6   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 7   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 8   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 9   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 10  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 11  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 12  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 13  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 14  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 15  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 16  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 17  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 18  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
# 19  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...           64        5
#
#      ...           lon  Year   oshpd_id                     FACILITY_NAME  \
# 0    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 1    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 2    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 3    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 4    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 5    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 6    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 7    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 8    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 9    ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 10   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 11   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 12   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 13   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 14   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 15   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 16   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 17   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 18   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
# 19   ...   -118.144096  2014  106190017  ALHAMBRA HOSPITAL MEDICAL CENTER
#
#     COUNTY_NAME         Type_Of_Control           ED_Level    Source  \
# 0   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 1   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 2   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 3   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 4   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 5   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 6   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 7   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 8   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 9   LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 10  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 11  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 12  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 13  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 14  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 15  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 16  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 17  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Visit
# 18  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Admit
# 19  LOS ANGELES  Investor - Partnership  Emergency - Basic  ED Admit
#
#                Principal Diagnosis Group Count_y
# 0                        All Pregnancies     158
# 1             Blood/Blood-forming Organs      83
# 2                            Circulatory     222
# 3   Congenital Anomalies (Birth Defects)       3
# 4                              Digestive     940
# 5                   Endocrine/Metabolism     162
# 6                          Genitourinary     880
# 7                             Infections     213
# 8           Injuries/Drugs/Complications    2731
# 9                        Musculoskeletal     982
# 10                             Neoplasms      13
# 11             Nervous & Sensory Systems     708
# 12     Other Reasons for Health Services     291
# 13                   Perinatal Disorders       1
# 14                  Psychoses & Neurosis     519
# 15                             Respitory    1186
# 16                        Skin Disorders     554
# 17                              Symptoms    2294
# 18                       All Pregnancies       4
# 19            Blood/Blood-forming Organs     101
#
# [20 rows x 26 columns]

# %%
laInjuriesDrugsComplications = laERData[laERData["Principal Diagnosis Group"] == "Injuries/Drugs/Complications"]
print len(laInjuriesDrugsComplications)
laInjuriesDrugsComplications.head(20)
# Out:
# 108
#           County Code  Perm ID  \
# 8    19 - Los Angeles    11386
# 25   19 - Los Angeles    11386
# 42   19 - Los Angeles    11399
# 60   19 - Los Angeles    11399
# 81   19 - Los Angeles    11441
# 99   19 - Los Angeles    11441
# 119  19 - Los Angeles    11480
# 136  19 - Los Angeles    11480
# 156  19 - Los Angeles    11410
# 170  19 - Los Angeles    11410
# 182  19 - Los Angeles    11510
# 199  19 - Los Angeles    11510
# 221  19 - Los Angeles    11748
# 238  19 - Los Angeles    11748
# 255  19 - Los Angeles    11971
# 272  19 - Los Angeles    11971
# 293  19 - Los Angeles    12088
# 310  19 - Los Angeles    12088
# 328  19 - Los Angeles    11927
# 346  19 - Los Angeles    11927
#
#                                         Facility Name Building Nbr  \
# 8                    ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 25                   ALHAMBRA HOSPITAL MEDICAL CENTER    BLD-00722
# 42                           ANTELOPE VALLEY HOSPITAL    BLD-00737
# 60                           ANTELOPE VALLEY HOSPITAL    BLD-00737
# 81                                   BEVERLY HOSPITAL    BLD-00613
# 99                                   BEVERLY HOSPITAL    BLD-00613
# 119  CALIFORNIA HOSPITAL MEDICAL CENTER - LOS ANGELES    BLD-00622
# 136  CALIFORNIA HOSPITAL MEDICAL CENTER - LOS ANGELES    BLD-00622
# 156                    CATALINA ISLAND MEDICAL CENTER    BLD-00725
# 170                    CATALINA ISLAND MEDICAL CENTER    BLD-00725
# 182                 CENTINELA HOSPITAL MEDICAL CENTER    BLD-00633
# 199                 CENTINELA HOSPITAL MEDICAL CENTER    BLD-00633
# 221          CITRUS VALLEY MEDICAL CENTER - IC CAMPUS    BLD-02019
# 238          CITRUS VALLEY MEDICAL CENTER - IC CAMPUS    BLD-02019
# 255          CITRUS VALLEY MEDICAL CENTER - QV CAMPUS    BLD-01163
# 272          CITRUS VALLEY MEDICAL CENTER - QV CAMPUS    BLD-01163
# 293                              COAST PLAZA HOSPITAL    BLD-02151
# 310                              COAST PLAZA HOSPITAL    BLD-02151
# 328                            COLLEGE MEDICAL CENTER    BLD-00402
# 346                            COLLEGE MEDICAL CENTER    BLD-00402
#
#                               Building Name Building Status SPC Rating *  \
# 8                                  Hospital      In Service            2
# 25                                 Hospital      In Service            2
# 42                        Original Hospital      In Service            1
# 60                        Original Hospital      In Service            1
# 81   Service Building & Additions (Block I)      In Service            1
# 99   Service Building & Additions (Block I)      In Service            1
# 119                        Tibbitts Tower A      In Service            3
# 136                        Tibbitts Tower A      In Service            3
# 156                       Original Building      In Service            2
# 170                       Original Building      In Service            2
# 182                   West Wing/ER Addition      In Service            2
# 199                   West Wing/ER Addition      In Service            2
# 221                       Original Building      In Service            2
# 238                       Original Building      In Service            2
# 255                           Main Building      In Service            1
# 272                           Main Building      In Service            1
# 293                       Original Building      In Service            2
# 310                       Original Building      In Service            2
# 328                    North and East Wings      In Service            2
# 346                    North and East Wings      In Service            2
#
#                                           Building URL  Height (ft)  Stories  \
# 8    https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        64.00        5
# 25   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        64.00        5
# 42   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        34.50        3
# 60   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        34.50        3
# 81   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        10.00        1
# 99   https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        10.00        1
# 119  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        8
# 136  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...          NaN        8
# 156  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...         9.30        1
# 170  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...         9.30        1
# 182  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        12.00        1
# 199  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        12.00        1
# 221  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        22.75        2
# 238  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        22.75        2
# 255  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        74.00        6
# 272  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        74.00        6
# 293  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        14.00        1
# 310  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        14.00        1
# 328  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        24.00        2
# 346  https://eserv.oshpd.ca.gov/CitizenAccess/Cap/C...        24.00        2
#
#       ...           lon  Year   oshpd_id  \
# 8     ...   -118.144096  2014  106190017
# 25    ...   -118.144096  2014  106190017
# 42    ...   -118.157982  2014  106190034
# 60    ...   -118.157982  2014  106190034
# 81    ...   -118.100639  2014  106190081
# 99    ...   -118.100639  2014  106190081
# 119   ...   -118.265467  2014  106190125
# 136   ...   -118.265467  2014  106190125
# 156   ...   -118.331185  2014  106190045
# 170   ...   -118.331185  2014  106190045
# 182   ...   -118.348282  2014  106190148
# 199   ...   -118.348282  2014  106190148
# 221   ...   -117.893410  2014  106190413
# 238   ...   -117.893410  2014  106190413
# 255   ...   -117.944466  2014  106190636
# 272   ...   -117.944466  2014  106190636
# 293   ...   -118.098457  2014  106190766
# 310   ...   -118.098457  2014  106190766
# 328   ...   -118.193047  2014  106190587
# 346   ...   -118.193047  2014  106190587
#
#                                         FACILITY_NAME  COUNTY_NAME  \
# 8                    ALHAMBRA HOSPITAL MEDICAL CENTER  LOS ANGELES
# 25                   ALHAMBRA HOSPITAL MEDICAL CENTER  LOS ANGELES
# 42                           ANTELOPE VALLEY HOSPITAL  LOS ANGELES
# 60                           ANTELOPE VALLEY HOSPITAL  LOS ANGELES
# 81                                   BEVERLY HOSPITAL  LOS ANGELES
# 99                                   BEVERLY HOSPITAL  LOS ANGELES
# 119  CALIFORNIA HOSPITAL MEDICAL CENTER - LOS ANGELES  LOS ANGELES
# 136  CALIFORNIA HOSPITAL MEDICAL CENTER - LOS ANGELES  LOS ANGELES
# 156                    CATALINA ISLAND MEDICAL CENTER  LOS ANGELES
# 170                    CATALINA ISLAND MEDICAL CENTER  LOS ANGELES
# 182                 CENTINELA HOSPITAL MEDICAL CENTER  LOS ANGELES
# 199                 CENTINELA HOSPITAL MEDICAL CENTER  LOS ANGELES
# 221          CITRUS VALLEY MEDICAL CENTER - IC CAMPUS  LOS ANGELES
# 238          CITRUS VALLEY MEDICAL CENTER - IC CAMPUS  LOS ANGELES
# 255          CITRUS VALLEY MEDICAL CENTER - QV CAMPUS  LOS ANGELES
# 272          CITRUS VALLEY MEDICAL CENTER - QV CAMPUS  LOS ANGELES
# 293                              COAST PLAZA HOSPITAL  LOS ANGELES
# 310                              COAST PLAZA HOSPITAL  LOS ANGELES
# 328                            COLLEGE MEDICAL CENTER  LOS ANGELES
# 346                            COLLEGE MEDICAL CENTER  LOS ANGELES
#
#                           Type_Of_Control             ED_Level    Source  \
# 8                  Investor - Partnership    Emergency - Basic  ED Visit
# 25                 Investor - Partnership    Emergency - Basic  ED Admit
# 42                      Public - District    Emergency - Basic  ED Visit
# 60                      Public - District    Emergency - Basic  ED Admit
# 81                Nonprofit - Corporation    Emergency - Basic  ED Visit
# 99                Nonprofit - Corporation    Emergency - Basic  ED Admit
# 119               Nonprofit - Corporation    Emergency - Basic  ED Visit
# 136               Nonprofit - Corporation    Emergency - Basic  ED Admit
# 156               Nonprofit - Corporation  Emergency - Standby  ED Visit
# 170               Nonprofit - Corporation  Emergency - Standby  ED Admit
# 182  Investor - Limited Liability Company    Emergency - Basic  ED Visit
# 199  Investor - Limited Liability Company    Emergency - Basic  ED Admit
# 221               Nonprofit - Corporation    Emergency - Basic  ED Visit
# 238               Nonprofit - Corporation    Emergency - Basic  ED Admit
# 255               Nonprofit - Corporation    Emergency - Basic  ED Visit
# 272               Nonprofit - Corporation    Emergency - Basic  ED Admit
# 293  Investor - Limited Liability Company    Emergency - Basic  ED Visit
# 310  Investor - Limited Liability Company    Emergency - Basic  ED Admit
# 328  Investor - Limited Liability Company    Emergency - Basic  ED Visit
# 346  Investor - Limited Liability Company    Emergency - Basic  ED Admit
#
#         Principal Diagnosis Group Count_y
# 8    Injuries/Drugs/Complications    2731
# 25   Injuries/Drugs/Complications     198
# 42   Injuries/Drugs/Complications   17181
# 60   Injuries/Drugs/Complications    1646
# 81   Injuries/Drugs/Complications    5032
# 99   Injuries/Drugs/Complications     467
# 119  Injuries/Drugs/Complications   12823
# 136  Injuries/Drugs/Complications    1719
# 156  Injuries/Drugs/Complications     614
# 170  Injuries/Drugs/Complications       1
# 182  Injuries/Drugs/Complications   11015
# 199  Injuries/Drugs/Complications    1058
# 221  Injuries/Drugs/Complications    2840
# 238  Injuries/Drugs/Complications     411
# 255  Injuries/Drugs/Complications    9615
# 272  Injuries/Drugs/Complications     654
# 293  Injuries/Drugs/Complications    3119
# 310  Injuries/Drugs/Complications     182
# 328  Injuries/Drugs/Complications    1707
# 346  Injuries/Drugs/Complications     163
#
# [20 rows x 26 columns]

# %%
# %matplotlib inline

from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

mapMargin = 0.1
lowerLat = min(laInjuriesDrugsComplications["lat"]) - mapMargin
upperLat = max(laInjuriesDrugsComplications["lat"]) + mapMargin
lowerLon = min(laInjuriesDrugsComplications["lon"]) - mapMargin
upperLon = max(laInjuriesDrugsComplications["lon"]) + mapMargin
m = Basemap(projection='cass',llcrnrlat=lowerLat,urcrnrlat=upperLat,\
            llcrnrlon=lowerLon,urcrnrlon=upperLon,lat_ts=20,resolution='h',lon_0=(upperLon + lowerLon)/2.0,lat_0=(upperLat + lowerLat)/2.0)
m.drawcoastlines()
m.fillcontinents(color='#ffcccc',lake_color='aqua',zorder=0)
# draw parallels and meridians.
#m.drawparallels(np.arange(-90.,91.,30.))
#m.drawmeridians(np.arange(-180.,181.,60.))
m.drawmapboundary(fill_color='aqua')
x, y = m(laInjuriesDrugsComplications["lon"].values, laInjuriesDrugsComplications["lat"].values)
m.scatter(x, y, marker='o', color='k', s=2)
plt.title("Locations of LA Hospitals w/ ER Data on Injuries/Drugs/Complications")
plt.show()
